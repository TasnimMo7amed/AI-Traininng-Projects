# %% [markdown]
# # Download the datasets

# %% [markdown]
# https://www.kaggle.com/kmader/skin-cancer-mnist-ham10000

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image

np.random.seed(42)
from sklearn.metrics import confusion_matrix

import keras
from keras.utils.np_utils import to_categorical # used for converting labels to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn.preprocessing import LabelEncoder

# %%
skin_df = pd.read_csv('data/HAM10000_metadata.csv')
skin_df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
SIZE=32

# label encoding to numeric values from text
le = LabelEncoder()
le.fit(skin_df['dx'])
LabelEncoder()
print(list(le.classes_))
# Out:
# ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# %%
skin_df['label'] = le.transform(skin_df["dx"]) 
print(skin_df.sample(10))
# Out:
#         lesion_id      image_id   dx    dx_type   age     sex  \
# 1617  HAM_0007180  ISIC_0033272  mel      histo  65.0    male
# 8128  HAM_0007195  ISIC_0031923   nv      histo  40.0  female
# 2168  HAM_0001835  ISIC_0026652  mel      histo  65.0    male
# 1090  HAM_0000465  ISIC_0030583  bkl  consensus  35.0  female
# 7754  HAM_0001720  ISIC_0034010   nv      histo  45.0    male
# 8071  HAM_0006333  ISIC_0024424   nv      histo  35.0    male
# 7423  HAM_0004548  ISIC_0032832   nv      histo  45.0  female
# 8984  HAM_0006526  ISIC_0026671   nv      histo  55.0    male
# 2310  HAM_0003102  ISIC_0032389  mel      histo  65.0    male
# 7256  HAM_0004260  ISIC_0025525   nv      histo  65.0    male
#
#          localization  label
# 1617             face      4
# 8128  lower extremity      5
# 2168             back      4
# 1090            trunk      2
# 7754          abdomen      5
# 8071            trunk      5
# 7423  upper extremity      5
# 8984  lower extremity      5
# 2310             face      4
# 7256             back      5

# %%
skin_df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#        label
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2
# ...      ...
# 10010      0
# 10011      0
# 10012      0
# 10013      0
# 10014      4
#
# [10015 rows x 8 columns]

# %%
# Data distribution visualization

fig = plt.figure(figsize=(15,10))

ax1 = fig.add_subplot(221)
skin_df['dx'].value_counts().plot(kind='bar', ax=ax1)
ax1.set_ylabel('Count')
ax1.set_title('Cell Type');


ax2 = fig.add_subplot(223)
skin_df['localization'].value_counts().plot(kind='bar',color='green')
ax2.set_ylabel('Count',size=12)
ax2.set_title('Localization')


plt.tight_layout()
plt.show()

# %%
# Distribution of data into various classes 
from sklearn.utils import resample
print(skin_df['label'].value_counts())
# Out:
# 5    6705
# 4    1113
# 2    1099
# 1     514
# 0     327
# 6     142
# 3     115
# Name: label, dtype: int64

# %%
#Balance data.

df_0 = skin_df[skin_df['label'] == 0]
df_1 = skin_df[skin_df['label'] == 1]
df_2 = skin_df[skin_df['label'] == 2]
df_3 = skin_df[skin_df['label'] == 3]
df_4 = skin_df[skin_df['label'] == 4]
df_5 = skin_df[skin_df['label'] == 5]
df_6 = skin_df[skin_df['label'] == 6]

n_samples=500 
df_0_balanced = resample(df_0, replace=True, n_samples=n_samples, random_state=42) 
df_1_balanced = resample(df_1, replace=True, n_samples=n_samples, random_state=42) 
df_2_balanced = resample(df_2, replace=True, n_samples=n_samples, random_state=42)
df_3_balanced = resample(df_3, replace=True, n_samples=n_samples, random_state=42)
df_4_balanced = resample(df_4, replace=True, n_samples=n_samples, random_state=42)
df_5_balanced = resample(df_5, replace=True, n_samples=n_samples, random_state=42)
df_6_balanced = resample(df_6, replace=True, n_samples=n_samples, random_state=42)

skin_df_balanced = pd.concat([df_0_balanced, df_1_balanced, 
                              df_2_balanced, df_3_balanced, 
                              df_4_balanced, df_5_balanced, df_6_balanced])

# %%
#Now time to read images based on image ID from the CSV file
#This is the safest way to read images as it ensures the right image is read for the right ID
print(skin_df_balanced['label'].value_counts())
# Out:
# 0    500
# 1    500
# 2    500
# 3    500
# 4    500
# 5    500
# 6    500
# Name: label, dtype: int64

# %%
#Define the path and add as a new column
skin_df_balanced['path']='data/HAM10000/'+skin_df_balanced['image_id']+'.jpg'

# %%
#Use the path to read images.
skin_df_balanced['image'] = skin_df_balanced['path'].map(lambda x:np.asarray(Image.open(x).resize((SIZE,SIZE))))

# %%
n_samples = 5

# Plot
fig, m_axs = plt.subplots(7, n_samples, figsize = (4*n_samples, 3*7))
for n_axs, (type_name, type_rows) in zip(m_axs, 
                                         skin_df_balanced.sort_values(['dx']).groupby('dx')):
    n_axs[0].set_title(type_name)
    for c_ax, (_, c_row) in zip(n_axs, type_rows.sample(n_samples, random_state=1234).iterrows()):
        c_ax.imshow(c_row['image'])
        c_ax.axis('off')

# %%
#Convert dataframe column of images into numpy array
X = np.asarray(skin_df_balanced['image'].tolist())
X = X/255. # Scale values to 0-1. You can also used standardscaler or other scaling methods.

# %%
Y=skin_df_balanced['label'] #Assign label values to Y
Y_cat = to_categorical(Y, num_classes=7) #Convert to categorical as this is a multiclass classification problem

# %%
#Split to training and testing
x_train, x_test, y_train, y_test = train_test_split(X, Y_cat, test_size=0.25, random_state=42)

# %%
#Define the model.
#I've used autokeras to find out the best model for this problem.

num_classes = 7

model = Sequential()
model.add(Conv2D(256, (3, 3), activation="relu", input_shape=(SIZE, SIZE, 3)))

#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))  
model.add(Dropout(0.3))
model.add(Conv2D(128, (3, 3),activation='relu'))

#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))  
model.add(Dropout(0.3))
model.add(Conv2D(64, (3, 3),activation='relu'))

#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))  
model.add(Dropout(0.3))
model.add(Flatten())

model.add(Dense(32))
model.add(Dense(7, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['acc'])
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 30, 30, 256)       7168
#
#  max_pooling2d_18 (MaxPoolin  (None, 15, 15, 256)      0
#  g2D)
#
#  dropout_18 (Dropout)        (None, 15, 15, 256)       0
#
#  conv2d_19 (Conv2D)          (None, 13, 13, 128)       295040
#
#  max_pooling2d_19 (MaxPoolin  (None, 6, 6, 128)        0
#  g2D)
#
#  dropout_19 (Dropout)        (None, 6, 6, 128)         0
#
#  conv2d_20 (Conv2D)          (None, 4, 4, 64)          73792
#
#  max_pooling2d_20 (MaxPoolin  (None, 2, 2, 64)         0
#  g2D)
#
#  dropout_20 (Dropout)        (None, 2, 2, 64)          0
#
#  flatten_6 (Flatten)         (None, 256)               0
#
#  dense_12 (Dense)            (None, 32)                8224
#
#  dense_13 (Dense)            (None, 7)                 231
#
# =================================================================
# Total params: 384,455
# Trainable params: 384,455
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=2)

# %%
# Train
#You can also use generator to use augmentation during training.

batch_size = 16 
epochs = 60

history = model.fit(
    x_train, y_train,
    epochs=epochs,
    batch_size = batch_size,
    validation_data=(x_test, y_test),
    verbose=2)

score = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/60
# 165/165 - 10s - loss: 0.7492 - acc: 0.7227 - val_loss: 0.8522 - val_acc: 0.7086 - 10s/epoch - 60ms/step
# Epoch 2/60
# 165/165 - 10s - loss: 0.6542 - acc: 0.7490 - val_loss: 0.8151 - val_acc: 0.7269 - 10s/epoch - 60ms/step
# Epoch 3/60
# 165/165 - 10s - loss: 0.6424 - acc: 0.7543 - val_loss: 0.7748 - val_acc: 0.7451 - 10s/epoch - 60ms/step
# Epoch 4/60
# 165/165 - 10s - loss: 0.6471 - acc: 0.7585 - val_loss: 0.8015 - val_acc: 0.7326 - 10s/epoch - 61ms/step
# Epoch 5/60
# 165/165 - 10s - loss: 0.6057 - acc: 0.7608 - val_loss: 0.8158 - val_acc: 0.7234 - 10s/epoch - 60ms/step
# Epoch 6/60
# 165/165 - 10s - loss: 0.6392 - acc: 0.7646 - val_loss: 1.0084 - val_acc: 0.6640 - 10s/epoch - 61ms/step
# Epoch 7/60
# 165/165 - 10s - loss: 0.6024 - acc: 0.7699 - val_loss: 0.7801 - val_acc: 0.7291 - 10s/epoch - 60ms/step
# Epoch 8/60
# 165/165 - 10s - loss: 0.6145 - acc: 0.7794 - val_loss: 0.7925 - val_acc: 0.7349 - 10s/epoch - 60ms/step
# Epoch 9/60
# 165/165 - 10s - loss: 0.6106 - acc: 0.7684 - val_loss: 0.8098 - val_acc: 0.7257 - 10s/epoch - 60ms/step
# Epoch 10/60
# 165/165 - 10s - loss: 0.6322 - acc: 0.7623 - val_loss: 0.7809 - val_acc: 0.7463 - 10s/epoch - 61ms/step
# Epoch 11/60
# 165/165 - 10s - loss: 0.5999 - acc: 0.7787 - val_loss: 0.7930 - val_acc: 0.7337 - 10s/epoch - 61ms/step
# Epoch 12/60
# 165/165 - 10s - loss: 0.6117 - acc: 0.7749 - val_loss: 0.7872 - val_acc: 0.7463 - 10s/epoch - 61ms/step
# Epoch 13/60
# 165/165 - 10s - loss: 0.6152 - acc: 0.7672 - val_loss: 0.7977 - val_acc: 0.7394 - 10s/epoch - 60ms/step
# Epoch 14/60
# 165/165 - 10s - loss: 0.5850 - acc: 0.7749 - val_loss: 0.7717 - val_acc: 0.7383 - 10s/epoch - 60ms/step
# Epoch 15/60
# 165/165 - 10s - loss: 0.5821 - acc: 0.7817 - val_loss: 0.7631 - val_acc: 0.7543 - 10s/epoch - 60ms/step
# Epoch 16/60
# 165/165 - 10s - loss: 0.5856 - acc: 0.7787 - val_loss: 0.7523 - val_acc: 0.7554 - 10s/epoch - 61ms/step
# Epoch 17/60
# 165/165 - 11s - loss: 0.5710 - acc: 0.7863 - val_loss: 0.7573 - val_acc: 0.7360 - 11s/epoch - 65ms/step
# Epoch 18/60
# 165/165 - 10s - loss: 0.5592 - acc: 0.7810 - val_loss: 0.7820 - val_acc: 0.7509 - 10s/epoch - 63ms/step
# Epoch 19/60
# 165/165 - 10s - loss: 0.5787 - acc: 0.7832 - val_loss: 0.7784 - val_acc: 0.7257 - 10s/epoch - 61ms/step
# Epoch 20/60
# 165/165 - 11s - loss: 0.5898 - acc: 0.7783 - val_loss: 0.7887 - val_acc: 0.7486 - 11s/epoch - 65ms/step
# Epoch 21/60
# 165/165 - 11s - loss: 0.5921 - acc: 0.7771 - val_loss: 0.7279 - val_acc: 0.7691 - 11s/epoch - 67ms/step
# Epoch 22/60
# 165/165 - 11s - loss: 0.5554 - acc: 0.7981 - val_loss: 0.7061 - val_acc: 0.7589 - 11s/epoch - 66ms/step
# Epoch 23/60
# 165/165 - 11s - loss: 0.5549 - acc: 0.7870 - val_loss: 0.7576 - val_acc: 0.7611 - 11s/epoch - 65ms/step
# Epoch 24/60
# 165/165 - 11s - loss: 0.5329 - acc: 0.8080 - val_loss: 0.7283 - val_acc: 0.7714 - 11s/epoch - 68ms/step
# Epoch 25/60
# 165/165 - 10s - loss: 0.5885 - acc: 0.7691 - val_loss: 0.8085 - val_acc: 0.7291 - 10s/epoch - 62ms/step
# Epoch 26/60
# 165/165 - 10s - loss: 0.5601 - acc: 0.7935 - val_loss: 0.7354 - val_acc: 0.7554 - 10s/epoch - 61ms/step
# Epoch 27/60
# 165/165 - 11s - loss: 0.5538 - acc: 0.7897 - val_loss: 0.7775 - val_acc: 0.7417 - 11s/epoch - 64ms/step
# Epoch 28/60
# 165/165 - 10s - loss: 0.5671 - acc: 0.7867 - val_loss: 0.7363 - val_acc: 0.7646 - 10s/epoch - 62ms/step
# Epoch 29/60
# 165/165 - 11s - loss: 0.5714 - acc: 0.7863 - val_loss: 0.7122 - val_acc: 0.7691 - 11s/epoch - 64ms/step
# Epoch 30/60
# 165/165 - 10s - loss: 0.5169 - acc: 0.8088 - val_loss: 0.7787 - val_acc: 0.7497 - 10s/epoch - 64ms/step
# Epoch 31/60
# 165/165 - 10s - loss: 0.5885 - acc: 0.7741 - val_loss: 0.7619 - val_acc: 0.7474 - 10s/epoch - 61ms/step
# Epoch 32/60
# 165/165 - 10s - loss: 0.5370 - acc: 0.8008 - val_loss: 0.7686 - val_acc: 0.7577 - 10s/epoch - 61ms/step
# Epoch 33/60
# 165/165 - 11s - loss: 0.5214 - acc: 0.8156 - val_loss: 0.7485 - val_acc: 0.7543 - 11s/epoch - 64ms/step
# Epoch 34/60
# 165/165 - 10s - loss: 0.4965 - acc: 0.8164 - val_loss: 0.7859 - val_acc: 0.7394 - 10s/epoch - 61ms/step
# Epoch 35/60
# 165/165 - 10s - loss: 0.4937 - acc: 0.8164 - val_loss: 0.7568 - val_acc: 0.7611 - 10s/epoch - 60ms/step
# Epoch 36/60
# 165/165 - 10s - loss: 0.4901 - acc: 0.8282 - val_loss: 0.7224 - val_acc: 0.7566 - 10s/epoch - 60ms/step
# Epoch 37/60
# 165/165 - 10s - loss: 0.5008 - acc: 0.8118 - val_loss: 0.7474 - val_acc: 0.7611 - 10s/epoch - 60ms/step
# Epoch 38/60
# 165/165 - 10s - loss: 0.5286 - acc: 0.7981 - val_loss: 0.7980 - val_acc: 0.7371 - 10s/epoch - 61ms/step
# Epoch 39/60
# 165/165 - 10s - loss: 0.5277 - acc: 0.8034 - val_loss: 0.7385 - val_acc: 0.7589 - 10s/epoch - 62ms/step
# Epoch 40/60
# 165/165 - 10s - loss: 0.5042 - acc: 0.8149 - val_loss: 0.7335 - val_acc: 0.7600 - 10s/epoch - 61ms/step
# Epoch 41/60
# 165/165 - 10s - loss: 0.5075 - acc: 0.8095 - val_loss: 0.7623 - val_acc: 0.7417 - 10s/epoch - 60ms/step
# Epoch 42/60
# 165/165 - 10s - loss: 0.4801 - acc: 0.8187 - val_loss: 0.7404 - val_acc: 0.7509 - 10s/epoch - 60ms/step
# Epoch 43/60
# 165/165 - 10s - loss: 0.4956 - acc: 0.8103 - val_loss: 0.7413 - val_acc: 0.7680 - 10s/epoch - 60ms/step
# Epoch 44/60
# 165/165 - 10s - loss: 0.4782 - acc: 0.8160 - val_loss: 0.7712 - val_acc: 0.7566 - 10s/epoch - 61ms/step
# Epoch 45/60
# 165/165 - 10s - loss: 0.5228 - acc: 0.8126 - val_loss: 0.7399 - val_acc: 0.7577 - 10s/epoch - 62ms/step
# Epoch 46/60
# 165/165 - 10s - loss: 0.4601 - acc: 0.8259 - val_loss: 0.7580 - val_acc: 0.7611 - 10s/epoch - 61ms/step
# Epoch 47/60
# 165/165 - 10s - loss: 0.4899 - acc: 0.8240 - val_loss: 0.7303 - val_acc: 0.7691 - 10s/epoch - 60ms/step
# Epoch 48/60
# 165/165 - 10s - loss: 0.5207 - acc: 0.8126 - val_loss: 0.7645 - val_acc: 0.7623 - 10s/epoch - 60ms/step
# Epoch 49/60
# 165/165 - 10s - loss: 0.4846 - acc: 0.8240 - val_loss: 0.7577 - val_acc: 0.7737 - 10s/epoch - 61ms/step
# Epoch 50/60
# 165/165 - 10s - loss: 0.4484 - acc: 0.8309 - val_loss: 0.7416 - val_acc: 0.7726 - 10s/epoch - 60ms/step
# Epoch 51/60
# 165/165 - 10s - loss: 0.4811 - acc: 0.8255 - val_loss: 0.7891 - val_acc: 0.7589 - 10s/epoch - 62ms/step
# Epoch 52/60
# 165/165 - 10s - loss: 0.4743 - acc: 0.8270 - val_loss: 0.7904 - val_acc: 0.7531 - 10s/epoch - 61ms/step
# Epoch 53/60
# 165/165 - 10s - loss: 0.4963 - acc: 0.8145 - val_loss: 0.7282 - val_acc: 0.7646 - 10s/epoch - 60ms/step
# Epoch 54/60
# 165/165 - 10s - loss: 0.4657 - acc: 0.8213 - val_loss: 0.8244 - val_acc: 0.7486 - 10s/epoch - 61ms/step
# Epoch 55/60
# 165/165 - 10s - loss: 0.4599 - acc: 0.8335 - val_loss: 0.8109 - val_acc: 0.7543 - 10s/epoch - 61ms/step
# Epoch 56/60
# 165/165 - 10s - loss: 0.4791 - acc: 0.8270 - val_loss: 0.7745 - val_acc: 0.7646 - 10s/epoch - 62ms/step
# Epoch 57/60
# 165/165 - 10s - loss: 0.4427 - acc: 0.8373 - val_loss: 0.7565 - val_acc: 0.7749 - 10s/epoch - 62ms/step
# Epoch 58/60
# 165/165 - 10s - loss: 0.4056 - acc: 0.8510 - val_loss: 0.7391 - val_acc: 0.7600 - 10s/epoch - 61ms/step
# Epoch 59/60
# 165/165 - 10s - loss: 0.4595 - acc: 0.8309 - val_loss: 0.8291 - val_acc: 0.7360 - 10s/epoch - 60ms/step
# Epoch 60/60
# 165/165 - 10s - loss: 0.4803 - acc: 0.8221 - val_loss: 0.7726 - val_acc: 0.7657 - 10s/epoch - 60ms/step
# 28/28 [==============================] - 1s 24ms/step - loss: 0.7726 - acc: 0.7657

# %%
print('Test accuracy:', score[1]*100,"%")
# Out:
# Test accuracy: 74.97143149375916 %

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['acc']
val_acc = history.history['val_acc']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Prediction on test data
y_pred = model.predict(x_test)
# Convert predictions classes to one hot vectors 
y_pred_classes = np.argmax(y_pred, axis = 1) 
# Convert test data to one hot vectors
y_true = np.argmax(y_test, axis = 1)
# Out:
# 28/28 [==============================] - 2s 54ms/step

# %%
#Print confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

fig, ax = plt.subplots(figsize=(20,20))
sns.set(font_scale=1.6)
sns.heatmap(cm, annot=True, linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:>
